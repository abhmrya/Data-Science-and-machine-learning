# %%
import pandas as pd
from io import StringIO

data = """Query,Intent,Disease,Answer
Hello,greeting,N/A,Hi there! How can I help you today?
Hi,greeting,N/A,Hello! What can I assist you with?
Hey,greeting,N/A,Hey! How are you feeling today?
What are the symptoms of malaria?,symptom_query,Malaria,Malaria symptoms often include high fever, shaking chills, severe headache, muscle aches, and fatigue. Some people also experience nausea and vomiting.
Tell me about malaria symptoms.,symptom_query,Malaria,The classic signs are cyclical fever spikes, intense chills, and sweating. These "attacks" can last for hours and repeat every few days.
How do I know if I have malaria?,symptom_query,Malaria,If you have a fever after visiting a malaria-prone area, especially with chills and headache, you should see a doctor immediately for a blood test.
Is malaria contagious?,basic_health_query,Malaria,No, malaria is not contagious from person to person. It is spread through the bite of an infected mosquito.
What is the best way to treat malaria?,treatment_query,Malaria,The best treatment for malaria is an Artemisinin-based Combination Therapy (ACT), prescribed by a doctor. The specific medication depends on the type of parasite and the region.
What medication is used for malaria?,treatment_query,Malaria,Common medications include Artemisinin-based Combination Therapies (ACTs), chloroquine (in areas without resistance), and mefloquine. A doctor will determine the right one for you.
How long does malaria treatment take?,treatment_query,Malaria,Malaria is curable within two weeks if diagnosed early and treated correctly. It's crucial to take the full course of medication.
Where to get malaria treatment?,treatment_query,Malaria,You should seek medical care from a doctor or a clinic, especially if you have recently traveled to an area with malaria.
How to prevent malaria?,prevention_query,Malaria,You can prevent malaria by using insect repellents, sleeping under insecticide-treated bed nets, and taking prophylactic medication when traveling to high-risk areas.
How can I avoid getting malaria?,prevention_query,Malaria,To avoid malaria, use bed nets, wear long clothing to cover your skin, and use an insect repellent that contains DEET or picaridin.
What are the causes of malaria?,cause_query,Malaria,Malaria is caused by a parasite of the genus Plasmodium, which is transmitted to humans through the bite of an infected female Anopheles mosquito.
How is malaria transmitted?,cause_query,Malaria,Malaria is primarily transmitted through mosquito bites. It can also be spread through blood transfusions, organ transplants, or from a mother to her unborn child.
What kind of parasite causes malaria?,cause_query,Malaria,Malaria is caused by five types of Plasmodium parasites: P. falciparum, P. vivax, P. ovale, P. malariae, and P. knowlesi. P. falciparum is the most severe type.
Who is at risk for malaria?,risk_query,Malaria,Infants, young children, pregnant women, and travelers from areas with no malaria are at a higher risk of severe infection.
What are the complications of malaria?,complication_query,Malaria,Untreated malaria can lead to serious complications such as cerebral malaria (affecting the brain), severe anemia, organ failure (kidneys, liver), and respiratory distress.
What is cerebral malaria?,complication_query,Malaria,Cerebral malaria is a severe complication where parasite-filled red blood cells block small blood vessels to the brain, which can cause seizures, coma, or brain damage.
How is malaria diagnosed?,diagnosis_query,Malaria,Malaria is diagnosed through a blood test. A doctor will examine a blood sample under a microscope to look for the parasites, or use a rapid diagnostic test (RDT) to detect specific antigens.
How accurate is a malaria test?,diagnosis_query,Malaria,A microscopic blood smear is considered the gold standard for diagnosis. RDTs are also very accurate for initial screening.
What are the different types of malaria?,types_query,Malaria,There are five types of malaria that infect humans, caused by the parasites: P. falciparum, P. vivax, P. ovale, P. malariae, and P. knowlesi.
Is there a vaccine for malaria?,prevention_query,Malaria,Yes, the WHO has approved a malaria vaccine, RTS,S/AS01, for use in children in areas with moderate to high malaria transmission. It is not yet widely available."""
df = pd.read_csv(data)
# print(df.head())
a=pd.DataFrame(df)
a
# a.to_excel("check.excel")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 28
#       2 from io import StringIO
#       4 data = """Query,Intent,Disease,Answer
#       5 Hello,greeting,N/A,Hi there! How can I help you today?
#       6 Hi,greeting,N/A,Hello! What can I assist you with?
#    (...)
#      26 What are the different types of malaria?,types_query,Malaria,There are five types of malaria that infect humans, caused by the parasites: P. falciparum, P. vivax, P. ovale, P. malariae, and P. knowlesi.
#      27 Is there a vaccine for malaria?,prevention_query,Malaria,Yes, the WHO has approved a malaria vaccine, RTS,S/AS01, for use in children in areas with moderate to high malaria transmission. It is not yet widely available."""
# ---> 28 df = pd.read_csv(data)
#      29 # print(df.head())
#      30 a=pd.DataFrame(df)
#
# ...
